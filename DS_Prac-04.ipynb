# %%
import seaborn as sns
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset/HousingData.csv")

# %%
data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
data.fillna(data.mean(), inplace=True)

# %%
missing_values = data.isnull().sum()
missing_values
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %%
data.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.545770   22.921051    6.699165    0.250233    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.083235    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.290250    0.000000    9.900000    0.000000    0.538000    6.208500
# 75%      3.611874   11.211934   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
X = data.drop('MEDV', axis=1)
y = data['MEDV']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=80, random_state=42)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([29.37281719, 36.44781102, 14.37789439, 24.95981262, 18.75959595,
#        23.23069809, 17.98388427, 14.10492543, 23.02446779, 20.99052996,
#        25.15486907, 18.81092332, -4.86933063, 21.67034768, 19.41398713,
#        25.52133263, 19.67200793,  6.89134825, 40.72032204, 17.60847061,
#        24.51277773, 30.39860764, 11.75447056, 22.42327362, 18.00162815,
#        16.28252359, 21.11901763, 14.78656301, 23.18736949, 19.58845097,
#        23.3144362 , 25.15097111, 25.97053115, 17.72282967, 17.17116991,
#        16.56393479, 30.7344547 , 20.25771442, 24.10683897, 22.11096755,
#        14.67753413, 32.71234591, 42.78558606, 17.77955042, 27.73825839,
#        17.2032869 , 14.42930376, 25.77238165, 20.39529377, 30.23482058,
#        21.19187758, 34.07510292, 16.2268767 , 26.26475121, 39.58934496,
#        22.43945413, 19.0274985 , 32.96417272, 25.28659255, 13.17693517,
#        22.38196245, 30.40517375, 31.41390745, 16.43549866, 20.08850859,
# ...

# %%
X_train
# Out:
#          CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 69    0.12816  12.5   6.07   0.0  0.409  5.885  33.0  6.4980    4  345
# 408   7.40389   0.0  18.10   0.0  0.597  5.617  97.9  1.4547   24  666
# 255   0.03548  80.0   3.64   0.0  0.392  5.876  19.1  9.2203    1  315
# 392  11.57790   0.0  18.10   0.0  0.700  5.036  97.0  1.7700   24  666
# 312   0.26169   0.0   9.90   0.0  0.544  6.023  90.4  2.8340    4  304
# ..        ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 106   0.17120   0.0   8.56   0.0  0.520  5.836  91.9  2.2110    5  384
# 270   0.29916  20.0   6.96   0.0  0.464  5.856  42.1  4.4290    3  223
# 348   0.01501  80.0   2.01   0.0  0.435  6.635  29.7  8.3440    4  280
# 435  11.16040   0.0  18.10   0.0  0.740  6.629  94.6  2.1247   24  666
# 102   0.22876   0.0   8.56   0.0  0.520  6.405  85.4  2.7147    5  384
#
#      PTRATIO       B  LSTAT
# 69      18.9  396.90   8.79
# 408     20.2  314.64  26.40
# ...

# %%
X_test
# Out:
#          CRIM    ZN      INDUS  CHAS     NOX     RM         AGE     DIS  RAD  \
# 173   0.09178   0.0  11.083992   0.0  0.5100  6.416   68.518519  2.6463    5
# 274   0.05644  40.0   6.410000   1.0  0.4470  6.758   32.900000  4.0776    4
# 491   0.10574   0.0  27.740000   0.0  0.6090  5.983   98.800000  1.8681    4
# 72    0.09164   0.0  10.810000   0.0  0.4130  6.065    7.800000  5.2873    4
# 452   5.09017   0.0  18.100000   0.0  0.7130  6.297   91.800000  2.3682   24
# ..        ...   ...        ...   ...     ...    ...         ...     ...  ...
# 398  38.35180   0.0  18.100000   0.0  0.6930  5.453  100.000000  1.4896   24
# 104   0.13960   0.0   8.560000   0.0  0.5200  6.167   90.000000  2.4210    5
# 203   0.03510  95.0   2.680000   0.0  0.4161  7.853   33.200000  5.1180    4
# 381  15.87440   0.0  18.100000   0.0  0.6710  6.545   99.100000  1.5192   24
# 489   0.18337   0.0  27.740000   0.0  0.6090  5.414   98.300000  1.7554    4
#
#      TAX  PTRATIO       B  LSTAT
# ...

# %%
y_train
# Out:
# 69     20.9
# 408    17.2
# 255    20.9
# 392     9.7
# 312    19.4
#        ...
# 106    19.5
# 270    21.1
# 348    24.5
# 435    13.4
# 102    18.6
# Name: MEDV, Length: 426, dtype: float64

# %%
y_test
# Out:
# 173    23.6
# 274    32.4
# 491    13.6
# 72     22.8
# 452    16.1
#        ...
# 398     5.0
# 104    20.1
# 203    48.5
# 381    10.9
# 489     7.0
# Name: MEDV, Length: 80, dtype: float64

# %%
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 14.407575969592624

# %%
import matplotlib.pyplot as plt
plt.scatter(y_test, y_pred)
plt.xlabel("Actual Prices")
plt.ylabel("Predicted Prices")
plt.title("Actual Prices vs Predicted Prices")
plt.show()

# %%
import matplotlib.pyplot as plt

# Create an index for the data points
index = range(len(y_test))

# Plot actual prices
plt.plot(index, y_test, label='Actual Prices', marker='o')

# Plot predicted prices
plt.plot(index, y_pred, label='Predicted Prices', marker='x')

plt.xlabel("Data Point Index")
plt.ylabel("Price")
plt.title("Actual Prices vs Predicted Prices")
plt.legend()
plt.show()

# %%
import pandas as pd
from sklearn.linear_model import LinearRegression

# Load the trained model
model = LinearRegression()
model.fit(X_train, y_train)

# Define a function to predict the price
def predict_price(features):
    # Convert features to DataFrame
    new_house_df = pd.DataFrame(features)

    # Predict the price using the trained model
    predicted_price = model.predict(new_house_df)

    return predicted_price[0]

# Define the features dictionary
features = {
    'CRIM': [0.01],
    'ZN': [20.0],
    'INDUS': [8.0],
    'CHAS': [0.0],
    'NOX': [0.5],
    'RM': [6.0],
    'AGE': [70.0],
    'DIS': [4.0],
    'RAD': [4],
    'TAX': [300],
    'PTRATIO': [18.0],
    'B': [380.0],
    'LSTAT': [10.0]
}

# Predict the price using the defined features
predicted_price = predict_price(features)

# Display the predicted price
print("Predicted Price:", predicted_price)
# Out:
# Predicted Price: 24.196413610701164

# %%
# Choose an index of a house from the dataset
house_index = 0  # For example, let's choose the first house

# Get the features of the chosen house from the dataset
house_features = X_test.iloc[house_index].values.reshape(1, -1)

# Get the actual price of the chosen house from the dataset
actual_price = y_test.iloc[house_index]

# Predict the price of the chosen house using the trained model
predicted_price = model.predict(house_features)

# Print the actual and predicted prices
print("Actual Price:", actual_price)
print("Predicted Price:", predicted_price[0])

# Calculate the difference between actual and predicted prices
difference = abs(actual_price - predicted_price[0])
print("Difference:", difference)
# Out:
# Actual Price: 23.6
# Predicted Price: 29.37281719350895
# Difference: 5.772817193508949
# /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
