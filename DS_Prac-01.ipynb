# %%
#Importing Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 2
#       1 #Importing Libraries
# ----> 2 import pandas as pd
#       3 import numpy as np
#       4 import matplotlib.pyplot as plt
#
# ModuleNotFoundError: No module named 'pandas'

# %%
#Reading Dataset
df=pd.read_csv('Iris.csv')
print(df.to_string())

# %%
# !pip3 show pandas
# !pip3 install --upgrade --force-reinstall pandas
# Out:
# ...
#   Using cached pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl.metadata (19 kB)
# ...
#   Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl.metadata (61 kB)
# ...
#   Using cached python_dateutil-2.8.2-py2.py3-none-any.whl (247 kB)
# ...
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# ...
#   Using cached tzdata-2023.4-py2.py3-none-any.whl.metadata (1.4 kB)
# ...
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Using cached pandas-2.2.0-cp312-cp312-macosx_10_9_x86_64.whl (12.5 MB)
# Using cached numpy-1.26.4-cp312-cp312-macosx_10_9_x86_64.whl (20.3 MB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Using cached tzdata-2023.4-py2.py3-none-any.whl (346 kB)
# ...
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2024.1
#     Uninstalling pytz-2024.1:
#       Successfully uninstalled pytz-2024.1
#   Attempting uninstall: tzdata
#     Found existing installation: tzdata 2023.4
#     Uninstalling tzdata-2023.4:
# ...

# %%
df.describe()

# %%
numpy_array=df.to_numpy()

# %%
df.head(30)
# Out:
#     sepal_length  sepal_width  petal_length  petal_width      species
# 0            5.1          3.5           1.4          0.2  Iris-setosa
# 1            4.9          3.0           1.4          0.2  Iris-setosa
# 2            4.7          3.2           1.3          0.2  Iris-setosa
# 3            4.6          3.1           1.5          0.2  Iris-setosa
# 4            5.0          3.6           1.4          0.2  Iris-setosa
# 5            5.4          3.9           1.7          0.4  Iris-setosa
# 6            4.6          3.4           1.4          0.3  Iris-setosa
# 7            5.0          3.4           1.5          0.2  Iris-setosa
# 8            4.4          2.9           1.4          0.2  Iris-setosa
# 9            4.9          3.1           1.5          0.1  Iris-setosa
# 10           5.4          3.7           1.5          0.2  Iris-setosa
# 11           4.8          3.4           1.6          0.2  Iris-setosa
# ...

# %%
df.isna() # True means null values are present
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0           False        False         False        False    False
# 1           False        False         False        False    False
# 2           False        False         False        False    False
# 3           False        False         False        False    False
# 4           False        False         False        False    False
# ..            ...          ...           ...          ...      ...
# 145         False        False         False        False    False
# 146         False        False         False        False    False
# 147         False        False         False        False    False
# 148         False        False         False        False    False
# 149         False        False         False        False    False
#
# [150 rows x 5 columns]

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
variable_descriptions = df.dtypes
variable_descriptions
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
dimensions = df.shape
dimensions
# Out:
# (150, 5)

# %%
df.ndim
# Out:
# 2

# %%
data_get_dummies = pd.get_dummies(df, columns=['species'])
data_get_dummies
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  \
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
#      species_Iris-setosa  species_Iris-versicolor  species_Iris-virginica
# 0                   True                    False                   False
# 1                   True                    False                   False
# ...
